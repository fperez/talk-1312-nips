# %% [markdown]
# <p class="talk_title">IPython</p>
#
# <p class="subtitle">A multi-language architecture for interactive computing</p>
#
# <center>
#
# <p class="gap05"<p>
# <h2>[ipython.org](http://ipython.org)</h2>
#
# <p class="gap05"<p>
# <h3> Fernando Pérez </h3>
# <h3>[fperez.org](http://fperez.org), [@fperez_org](http://twitter.com/fperez_org)</h3>
# <h3>U.C. Berkeley</h3>
#
# <p class="gap2"<p>
# </center>

# %%
# %pylab inline
# %run talktools
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>
#
# .rendered_html
# {
#   color: #2C5494;
#   /*font-family: Ubuntu; */
#   font-size: 140%;
#   line-height: 1.1;
#   margin: 0.5em 0;
#   }
#
# .talk_title
# {
#   color: #498AF3;
#   font-size: 250%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 10px 50px 10px;
#   }
#
# .subtitle
# {
#   color: #386BBC;
#   font-size: 180%;
#   font-weight:bold;
#   line-height: 1.2;
#   margin: 20px 50px 20px;
#   }
#
# .slide-header, p.slide-header
# {
#   color: #498AF3;
#   font-size: 200%;
#   font-weight:bold;
#   margin: 0px 20px 10px;
#   page-break-before: always;
#   text-align: center;
#   }
#
# .rendered_html h1
# {
#   color: #498AF3;
#   line-height: 1.2;
#   margin: 0.15em 0em 0.5em;
#   page-break-before: always;
#   text-align: center;
#   }
#
#
# .rendered_html h2
# {
#   color: #386BBC;
#   line-height: 1.2;
#   margin: 1.1em 0em 0.5em;
#   }
#
# .rendered_html h3
# {
#   font-size: 100%;
# ...

# %% [markdown]
# <div class="slide-header">Why IPython?</div>
#
# <center>
# *"The purpose of computing is insight, not numbers"*
# <p style="margin-left:70%">Hamming '62</p>
# </center>

# %% [markdown]
# ## The Lifecycle of a Scientific Idea (schematically)
#
# 1. <span class="emph">**Individual**</span> exploratory work
# 2. <span class="emph">**Collaborative**</span> development
# 3. <span class="emph">**Parallel**</span> production runs (HPC, cloud, ...)
# 4. <span class="emph">**Publication**</span> (with <span class="warn">reproducible</span> results!)
# 5. <span class="emph">**Education**</span>
# 6. Goto 1.

# %% [markdown]
# <div class="slide-header">From a better shell...</div>
# ## 2001, instead of a Physics dissertation
# <center>
# <img src="files/fig/ipython_console4.png" width="80%">
# </center>

# %% [markdown]
# <div class="slide-header">... to a fancier shell (and a protocol!)...</div>
# ## 2010, E Patterson, Enthought (key support!)
#
# <center>
# <img src="files/fig/ipython_qtconsole.png" width="40%">
# </center>

# %% [markdown]
# <div class="slide-header">... 6 notebook attempts over 6 years...</div>
# ## T. Matev, T. Alatalo, R. Kern, Min RK, J. Gao, B. Granger
# <center>
# <img src="files/fig/ipython-http.png" width="70%">
# </center>

# %% [markdown]
# # ... up to today's IPython Notebook
#
# ## Everyday exploratory computing, with annotations
#
# Let's plot the Bessel functions $J_i$ for $i=0,3,6,9$:

# %%
import scipy.special as spec
x = linspace(0, 20, 200)
for n in range(0,13,3):
    plot(x, spec.jn(n, x), label=r'$J_{%i}(x)$' % n)
grid()
legend()
title('Bessel Functions are neat');

# %% [markdown]
# # Explore parameters interactively

# %%
@interactive(x=(1, 10))
def f(x):
    print 'X is:', x
# Out:
# X is: 5

# %%
from sklearn import datasets

digits = datasets.load_digits()
n = len(digits.images)

@interactive(i=(0,n-1))
def view_image(i):
    print 'Classif. Label:', digits.target[i]
    plt.matshow(digits.images[i], cmap=cm.gray_r)
    plt.show()
# Out:
# Classif. Label: 7
# Figure(320x320)

# %% [markdown]
# <div class="slide-header">Displaying results: a rich protocol</div>

# %%
Image('fig/logo.png')

# %%
Video('fig/animation.m4v')  # Credit: Chris Kees, Army ERDC; created with Proteus.
# Out:
# <video controls alt="test" src="...">
#     </video>

# %% [markdown]
# # Browser multimedia + scientific visualization

# %%
plot_audio('voice.wav')
Audio('voice.wav')
# Out:
# <p>voice.wav:</p>
# <audio controls>
#     <source src="files/voice.wav" type="audio/wav">
#
# Your browser does not support the Audio element; you can play
# <a href="files/voice.wav">this file</a> manually.
# </audio>

# %% [markdown]
# # LaTeX and symbolic mathematics support

# %%
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
from sympy import symbols, Eq, factor, init_printing, expand
init_printing(use_latex=True)
x, y = symbols("x y")

# %%
eq = ((x+y)**3 * (x+1))
display(Eq(eq, expand(eq)))
# Out:
#                3    4      3      3      2  2      2        3        2    3
# (x + 1)⋅(x + y)  = x  + 3⋅x ⋅y + x  + 3⋅x ⋅y  + 3⋅x ⋅y + x⋅y  + 3⋅x⋅y  + y

# %%
@interactive(n=(1,10))
def _(n):
    eq = ((x+y)**n * (x+1))
    display(Eq(eq, expand(eq)))
# Out:
#                3    4      3      3      2  2      2        3        2    3
# (x + 1)⋅(x + y)  = x  + 3⋅x ⋅y + x  + 3⋅x ⋅y  + 3⋅x ⋅y + x⋅y  + 3⋅x⋅y  + y

# %% [markdown]
# # Dynamic graph visualizations with D3

# %% [markdown]
# # Talk to other languages: R (or Octave)

# %%
X = np.array([0,1,2,3,4])
Y = np.array([3,5,4,6,7])
# Now, load R support
# %load_ext rmagic
# Out:
# The rmagic extension is already loaded. To reload it, use:
#   %reload_ext rmagic

# %%
# %%R -i X,Y -o XYcoef
# XYlm = lm(Y~X)
# XYcoef = coef(XYlm)
# print(summary(XYlm))
# par(mfrow=c(2,2))
# plot(XYlm)
# Out:
# Call:
# lm(formula = Y ~ X)
#
# Residuals:
#    1    2    3    4    5
# -0.2  0.9 -1.0  0.1  0.2
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   3.2000     0.6164   5.191   0.0139 *
# X             0.9000     0.2517   3.576   0.0374 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7958 on 3 degrees of freedom
# Multiple R-squared:   0.81,	Adjusted R-squared:  0.7467
# F-statistic: 12.79 on 1 and 3 DF,  p-value: 0.03739

# %% [markdown]
# # Julia: seamless 2-way communication

# %%
# %load_ext julia.magic
# %julia @pyimport matplotlib.pyplot as plt
# %julia @pyimport numpy as np
# Out:
# Initializing Julia interpreter. This may take some time...

# %%
# %%julia
# # Note how we mix numpy and julia:
# x = linspace(0,2*pi,1000); # use the julia linspace
# y = sin(3*x + 4*np.cos(2*x)); # use the numpy cosine and julia sine
# plt.plot(x, y, color="red", linewidth=2.0, linestyle="--")
# Out:
# [Line2D(_line0)]
# Figure(480x320)

# %% [markdown]
# # Julia and Python
# ## The call stack as a layer cake

# %%
jfib = %julia jfib(n, fib) = n < 2 ? n : fib(n-1, jfib) + fib(n-2, jfib)
    
def pyfib(n, fib):
    if n < 2:
         return n
    return fib(n-1, pyfib) + fib(n-2, pyfib)

pyfib(20, jfib)   # Credit: Steven Johnson, MIT.
# Out:
# 6765

# %% [markdown]
# # Fortran integration

# %%
# %load_ext fortranmagic

# %%
# %%fortran
#
# subroutine f1(x, y, z)
#     real, intent(in) :: x,y
#     real, intent(out) :: z
#
#     z = sin(x+y)
#
# end subroutine f1

# %%
f1(1.0, 2.1415)
# Out:
# 9.26574066397734e-05

# %%
print f1.__doc__
# Out:
# f1 - Function signature:
#   z = f1(x,y)
# Required arguments:
#   x : input float
#   y : input float
# Return objects:
#   z : float

# %% [markdown]
# <div class="slide-header">nbconvert: notebook manipulation tools</div>
#
# * Library for format conversions
# * HTML, LaTeX, PDF output.
# * Basic command-line usage.
# * Rich customization possibilities.

# %% [markdown]
# <div class="slide-header">NBViewer: Share notebooks online </div>
# ## Matthias Bussonnier, 2012

# %%
website('nbviewer.ipython.org')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://nbviewer.ipython.org">nbviewer.ipython.org</a>
# </div>
# <iframe src="http://nbviewer.ipython.org"  width="800" height="450">

# %% [markdown]
# <div class="slide-header">Reproducible research...</div>
# ## Min RK, Brian, Greg Caporaso, Rob Knight (group), Justin Riley

# %%
website('http://www.nature.com/ismej/journal/v7/n3/full/ismej2012123a.html', 'Paper:')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://www.nature.com/ismej/journal/v7/n3/full/ismej2012123a.html">Paper:</a>
# </div>
# <iframe src="http://www.nature.com/ismej/journal/v7/n3/full/ismej2012123a.html"  width="800" height="450">

# %% [markdown]
# # Notebooks and AMI for reproducibility:

# %%
website('http://qiime.org/home_static/nih-cloud-apr2012', 'Companion Website:')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://qiime.org/home_static/nih-cloud-apr2012">Companion Website:</a>
# </div>
# <iframe src="http://qiime.org/home_static/nih-cloud-apr2012"  width="800" height="450">

# %% [markdown]
# <div class="slide-header">Notebook-based technical blogs</div>
# ## Jake VanderPlas (astronomy/ML at UW)

# %%
website('http://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets',
        'Pythonic Perambulations')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets">Pythonic Perambulations</a>
# </div>
# <iframe src="http://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets"  width="800" height="450">

# %% [markdown]
# <div class="slide-header">Training IBM Watson</div>
#
# ## Using Notebook and `IPython.parallel`
#
# * **From:** 8000 lines of Java, JS and HTML5, 2min/query
# * **To:** 200 lines of Python, 2sec/query

# %%
YouTubeVideo('tlontoyWX70',start='800', width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height=400"
#             src="http://www.youtube.com/embed/tlontoyWX70?start=800"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <div class="slide-header">Books: "Literate Computing"</div>
#
# By [Jose Unpingco](https://github.com/unpingco/Python-for-Signal-Processing)

# %%
website('http://link.springer.com/book/10.1007/978-3-319-01342-8/page/1',
        'Python for Signal Processing, featuring IPython Notebooks...')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://link.springer.com/book/10.1007/978-3-319-01342-8/page/1">Python for Signal Processing, featuring IPython Notebooks...</a>
# </div>
# <iframe src="http://link.springer.com/book/10.1007/978-3-319-01342-8/page/1"  width="800" height="450">

# %% [markdown]
# <div class="slide-header">... "Probabilistic Programming and Bayesian Methods for Hackers"</div>
# By [Cam Davidson Pilon](http://www.camdp.com).

# %%
website('camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers', 
        'Probabilistic programming...')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers">Probabilistic programming...</a>
# </div>
# <iframe src="http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers"  width="800" height="450">

# %% [markdown]
# <div class="slide-header">... "Mining the Social Web"</div>
# By [Matthew Russell](https://github.com/ptwobrussell).

# %%
website('http://shop.oreilly.com/product/0636920010203.do', 
        'Mining The Social Web')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://shop.oreilly.com/product/0636920010203.do">Mining The Social Web</a>
# </div>
# <iframe src="http://shop.oreilly.com/product/0636920010203.do"  width="800" height="450">

# %% [markdown]
# # CS 109: Data Science at Harvard

# %%
website('http://cs109.org/homework/homework.php', 'CS 109 Homeworks')
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://cs109.org/homework/homework.php">CS 109 Homeworks</a>
# </div>
# <iframe src="http://cs109.org/homework/homework.php"  width="800" height="450">

# %% [markdown]
# # A growing (and amazing) body of work
#
# <center>
# <h2> For much more: [http://ipython.org/gallery](http://ipython.org/gallery) </h2>
# </center>

# %% [markdown]
# <div class="slide-header">A simple and generic architecture</div>
# <center>
# <img src="files/fig/ipkernel_clients.png" width="50%">
# </center>

# %% [markdown]
# # `IPython.parallel`
# <center>
# <img src="files/fig/ipcluster.png" width="60%">
# </center>
# Image credit: Continuum Analytics.

# %% [markdown]
# <div class="slide-header">A protocol that enables kernels other languages</div>
#
# * IJulia
# * IHaskell
# * IFSharp
# * IRuby
# * IGo
# * In planning stages: R and Matlab.
#
# The interactive widget architecture is also 100% language-agnostic

# %% [markdown]
# <p class="gap2"></p>
# # A healthy ecosystem, OSS and commercial

# %% [markdown]
# # Emacs IPython Notebook Client
# ## Takafumi Arakaki
# <center>
# <img src="files/fig/emacs_ein_notebook_simple_plot.png" width="60%">
# </center>

# %% [markdown]
# # Vim client
# ## Paul Ivanov @Berkeley
# <center>
# <img src="files/fig/vim-ipython.png" width="80%">
# </center>

# %% [markdown]
# # Enthought Canopy
# <center>
# <img src="files/fig/ipython-canopy.png" width="80%">
# </center>

# %% [markdown]
# # Microsoft Python Tools for Visual Studio and Azure
# ### Shahrokh Mortazavi, Dino Viehland, Wenming Ye, Dennis Gannon. Thanks!!
# <center>
# <img src="files/fig/ipython-visual-studio-2.png" width="80%">
# </center>

# %% [markdown]
# <div class="slide-header">Microsoft Azure (S. Mortazavi, W. Ye)</div>
#
# <center>
# <img src="files/fig/azure-notebook.png" width="70%">
# </center>

# %% [markdown]
# # StarCluster
# ## Justin Riley @ MIT
# <center>
# <img src="files/fig/starcluster_overview.png" width="80%">
# </center>

# %% [markdown]
# # Continuum Analytics: Wakari
# <center>
# <img src="files/fig/wakari-pendulum.png" width="80%">
# </center>

# %% [markdown]
# # Cloud.sagemath.com: UW startup, W. Stein
#
# <center>
# <a href="https://cloud.sagemath.com/" target=_blank><img src="files/fig/cloud.sagemath-ipynb.png" width="80%"></a>
# </center>

# %% [markdown]
# # Plot.ly: interactive JS plots in Python

# %%
website('http://nbviewer.ipython.org/gist/jackparmer/7729584', 'Rosling Countries',
        width=900, height=600)
# Out:
# <div sytle="margin-bottom:10px">
# <a href="http://nbviewer.ipython.org/gist/jackparmer/7729584">Rosling Countries</a>
# </div>
# <iframe src="http://nbviewer.ipython.org/gist/jackparmer/7729584"  width="900" height="600">

# %% [markdown]
# ## The Core IPython team (2013)
# <img src="files/fig/ipython-team-2013.png" width="90%">
#
# **Plus** [Jonathan Frederic](https://github.com/jdfreder) and [Zach Sailer](https://github.com/Zsailer)!

# %% [markdown]
# ## An incomplete cast of characters
#
# * *Brian Granger* - Physics, Cal State San Luis Obispo
# * *Min Ragan-Kelley* - Nuclear Engineering, UC Berkeley
# * *Matthias Bussonnier* - Physics, Institut Curie, Paris
# * *Jonathan March*- Enthought
# * *Thomas Kluyver* - Biology, U. Sheffield
# * *Jörgen Stenarson* - Elect. Engineering, Sweden.
# * *Paul Ivanov* - Neuroscience, UC Berkeley.
# * *Robert Kern* - Enthought
# * *Evan Patterson* - Physics, Caltech/Enthought
# * *Brad Froehle* - Mathematics, UC Berkeley
# * Stefan van der Walt - UC Berkeley
# * John Hunter - TradeLink Securities, Chicago.
# * Prabhu Ramachandran - Aerospace Engineering, IIT Bombay.
# * Satra Ghosh- MIT Neuroscience
# * Gaël Varoquaux - Neurospin (Orsay, France)
# * Ville Vainio - CS, Tampere University of Technology, Finland
# * Barry Wark - Neuroscience, U. Washington.
# * Ondrej Certik - Physics, LANL
# * Darren Dale - Cornell
# * Justin Riley - MIT
# * Mark Voorhies - UC San Francisco
# * Nicholas Rougier - INRIA Nancy Grand Est
# * Thomas Spura - Fedora project
#
# Many more! (~220 commit authors)

# %% [markdown]
# # Public "Lab meetings on air"

# %%
YouTubeVideo('UUjTAq8cCcs', width=600, height=500)
# Out:
#         <iframe
#             width="600"
#             height=500"
#             src="http://www.youtube.com/embed/UUjTAq8cCcs"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Current IPython funding
#
# <img src="files/fig/sloan-logo.png" width=45%></img>
#
# <img src="files/fig/microsoft-logo.png" width=40%></img>
#
# <img src="files/fig/simons-logo.png" width=60%></img>
#
# <img src="files/fig/nsf-logo.png" width=10%></img>
#
# **Note:** We're hiring! Machine learning web pipelines for time-series analysis (astro, geo, neuro). With Josh Bloom (UCB Astro), NSF funding. Talk to me!

# %% [markdown]
# # Prior IPython support, thanks!!
#
# * **Enthought**, Austin, TX: Lots!
# * **Microsoft**: WinHPC support, Visual Studio integration, Azure
# * **DoD/DRC Inc**: 2011/12 (thanks to Jose Unpingco and Chris Keees).
# * Indirect: NIH via NiPy grant, NSF via Sage grant.
# * Google: summer of code 2005, 2010.
# * Tech-X Corp., Boulder, CO: Parallel/notebook (previous versions)

# %% [markdown]
# # A new $37.8M initiative in Data Science
#
# * Moore/Sloan Foundations, 5 year support for *UC Berkeley*, *U. Washington*, *NYU*.
# * Open source scientific computing tools will be central to this effort.
# * **We're hiring:** [Executive Director (now)](http://vcresearch.berkeley.edu/datascience/career-opportunities), Data Science Fellows (soon).
#
# <img src="files/fig/BIDS-launch-invite.jpg" width=70%></img>
